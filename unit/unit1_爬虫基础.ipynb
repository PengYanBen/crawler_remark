# %% [markdown]
# # 1.1 Http基本原理
#
# ## 1.URI 和 URL
# **URI** 的全称为 Uniform Resource ldentifier, 即统一资源标志符;<br>
# **URL** 的全称为 UniversalResource Locator， 即统一资源定位符。<br>
# ![image.png](attachment:image.png)<br>
#
# >基本组成格式：<br>
# ><b>scheme://[username:password@]hostname[ :port][/path][;parameters][?query][#fragment]</b>
#
# # 1.2 web网页基础
# # 1.3 爬虫的基础原理
# # 1.4 session与cookie
# # 1.5 代理的基本原理
# # 1.6 多线程与多进程的基本原理
